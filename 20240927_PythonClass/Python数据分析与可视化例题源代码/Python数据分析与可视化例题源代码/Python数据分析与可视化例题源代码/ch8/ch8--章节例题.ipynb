# %%
from pyecharts.charts import Bar
b = (Bar().add_xaxis(xaxis_data=["A","B","C"]).add_yaxis("aaa",[1,2,3]))
b.render_notebook()#显示图表
help(Bar.add_yaxis)
# Out:
# Help on function add_yaxis in module pyecharts.charts.basic_charts.bar:
#
# add_yaxis(self, series_name: str, y_axis: Sequence[Union[int, float, pyecharts.options.charts_options.BarItem, dict]], *, is_selected: bool = True, xaxis_index: Union[int, float, NoneType] = None, yaxis_index: Union[int, float, NoneType] = None, is_legend_hover_link: bool = True, color: Union[str, NoneType] = None, is_show_background: bool = False, background_style: Union[pyecharts.options.charts_options.BarBackgroundStyleOpts, dict, NoneType] = None, stack: Union[str, NoneType] = None, bar_width: Union[int, float, str] = None, bar_max_width: Union[int, float, str] = None, bar_min_width: Union[int, float, str] = None, bar_min_height: Union[int, float] = 0, category_gap: Union[int, float, str] = '20%', gap: Union[str, NoneType] = '30%', is_large: bool = False, large_threshold: Union[int, float] = 400, dimensions: Union[Sequence, NoneType] = None, series_layout_by: str = 'column', dataset_index: Union[int, float] = 0, is_clip: bool = True, z_level: Union[int, float] = 0, z: Union[int, float] = 2, label_opts: Union[pyecharts.options.series_options.LabelOpts, dict, NoneType] = <pyecharts.options.series_options.LabelOpts object at 0x000001E769C9EF48>, markpoint_opts: Union[pyecharts.options.series_options.MarkPointOpts, dict, NoneType] = None, markline_opts: Union[pyecharts.options.series_options.MarkLineOpts, dict, NoneType] = None, tooltip_opts: Union[pyecharts.options.global_options.TooltipOpts, dict, NoneType] = None, itemstyle_opts: Union[pyecharts.options.series_options.ItemStyleOpts, dict, NoneType] = None, encode: Union[str, pyecharts.commons.utils.JsCode, dict, NoneType] = None)

# %%
from pyecharts.charts import Liquid
c = Liquid().add(series_name='水球图',data = [0.6])
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="14122067565c4eff85801c92e78ac1b2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_14122067565c4eff85801c92e78ac1b2 = echarts.init(
#                     document.getElementById('14122067565c4eff85801c92e78ac1b2'), 'white', {renderer: 'canvas'});
#                 var option_14122067565c4eff85801c92e78ac1b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "\u6c34\u7403\u56fe",
#             "data": [
#                 0.6
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_14122067565c4eff85801c92e78ac1b2.setOption(option_14122067565c4eff85801c92e78ac1b2);
#         });
#     </script>

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
Bar().add_xaxis(["A","B","C"]).add_yaxis("趋势",[1,2,3]).set_global_opts(toolbox_opts = opts.ToolboxOpts(orient = 'vertical'),#工具栏设置
		 title_opts = opts.TitleOpts(title = "我是标题啊")).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="10a9286d1e7f477391a8d61026f18ed7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_10a9286d1e7f477391a8d61026f18ed7 = echarts.init(
#                     document.getElementById('10a9286d1e7f477391a8d61026f18ed7'), 'white', {renderer: 'canvas'});
#                 var option_10a9286d1e7f477391a8d61026f18ed7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8d8b\u52bf",
#             "legendHoverLink": true,
#             "data": [
#                 1,
#                 2,
#                 3
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8d8b\u52bf"
#             ],
#             "selected": {
#                 "\u8d8b\u52bf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "A",
#                 "B",
#                 "C"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6211\u662f\u6807\u9898\u554a",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "xAxisIndex": false,
#                 "yAxisIndex": false,
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             },
#             "brush": {
#                 "icon": {},
#                 "title": {
#                     "rect": "\u77e9\u5f62\u9009\u62e9",
#                     "polygon": "\u5708\u9009",
#                     "lineX": "\u6a2a\u5411\u9009\u62e9",
#                     "lineY": "\u7eb5\u5411\u9009\u62e9",
#                     "keep": "\u4fdd\u6301\u9009\u62e9",
#                     "clear": "\u6e05\u9664\u9009\u62e9"
#                 }
#             }
#         }
#     }
# };
#                 chart_10a9286d1e7f477391a8d61026f18ed7.setOption(option_10a9286d1e7f477391a8d61026f18ed7);
#         });
#     </script>

# %% [markdown]
# 【例8-1】利用Bar绘制柱状图。

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
# V1 版本开始支持链式调用
bar =  (Bar()
       .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", 
"高跟鞋", "袜子"])
       .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
       #.set_global_opts(title_opts = opts.TitleOpts(title = "某商场销售情况")) 
       )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d6fc406d247d4bf8a302ca9a59deb06a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d6fc406d247d4bf8a302ca9a59deb06a = echarts.init(
#                     document.getElementById('d6fc406d247d4bf8a302ca9a59deb06a'), 'white', {renderer: 'canvas'});
#                 var option_d6fc406d247d4bf8a302ca9a59deb06a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_d6fc406d247d4bf8a302ca9a59deb06a.setOption(option_d6fc406d247d4bf8a302ca9a59deb06a);
#         });
#     </script>

# %% [markdown]
# 【例8-2】并列柱状图绘制。

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
bar = Bar()
bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
bar.set_global_opts(title_opts = opts.TitleOpts(title = "货品销售情况",subtitle  =  "A和B公司"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bc3c3f750a8a4c119ef6346495fb7456" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bc3c3f750a8a4c119ef6346495fb7456 = echarts.init(
#                     document.getElementById('bc3c3f750a8a4c119ef6346495fb7456'), 'white', {renderer: 'canvas'});
#                 var option_bc3c3f750a8a4c119ef6346495fb7456 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u8d27\u54c1\u9500\u552e\u60c5\u51b5",
#             "subtext": "A\u548cB\u516c\u53f8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_bc3c3f750a8a4c119ef6346495fb7456.setOption(option_bc3c3f750a8a4c119ef6346495fb7456);
#         });
#     </script>

# %%
import pyecharts.charts
help(pyecharts.charts.basic_charts.bar)
# Out:
# Help on module pyecharts.charts.basic_charts.bar in pyecharts.charts.basic_charts:
#
# NAME
#     pyecharts.charts.basic_charts.bar
#
# CLASSES
#     pyecharts.charts.chart.RectChart(pyecharts.charts.chart.Chart)
#         Bar
#
#     class Bar(pyecharts.charts.chart.RectChart)
#      |  Bar(init_opts: Union[pyecharts.options.global_options.InitOpts, dict] = <pyecharts.options.global_options.InitOpts object at 0x000001E76D61D3C8>)
#      |
#      |  <<< Bar Chart >>>
#      |
#      |  Bar chart presents categorical data with rectangular bars
#      |  with heights or lengths proportional to the values that they represent.
#      |
#      |  Method resolution order:
#      |      Bar
#      |      pyecharts.charts.chart.RectChart
#      |      pyecharts.charts.chart.Chart
#      |      pyecharts.charts.base.Base
#      |      pyecharts.charts.mixins.ChartMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  add_yaxis(self, series_name: str, y_axis: Sequence[Union[int, float, pyecharts.options.charts_options.BarItem, dict]], *, is_selected: bool = True, xaxis_index: Union[int, float, NoneType] = None, yaxis_index: Union[int, float, NoneType] = None, is_legend_hover_link: bool = True, color: Union[str, NoneType] = None, is_show_background: bool = False, background_style: Union[pyecharts.options.charts_options.BarBackgroundStyleOpts, dict, NoneType] = None, stack: Union[str, NoneType] = None, bar_width: Union[int, float, str] = None, bar_max_width: Union[int, float, str] = None, bar_min_width: Union[int, float, str] = None, bar_min_height: Union[int, float] = 0, category_gap: Union[int, float, str] = '20%', gap: Union[str, NoneType] = '30%', is_large: bool = False, large_threshold: Union[int, float] = 400, dimensions: Union[Sequence, NoneType] = None, series_layout_by: str = 'column', dataset_index: Union[int, float] = 0, is_clip: bool = True, z_level: Union[int, float] = 0, z: Union[int, float] = 2, label_opts: Union[pyecharts.options.series_options.LabelOpts, dict, NoneType] = <pyecharts.options.series_options.LabelOpts object at 0x000001E769C9EF48>, markpoint_opts: Union[pyecharts.options.series_options.MarkPointOpts, dict, NoneType] = None, markline_opts: Union[pyecharts.options.series_options.MarkLineOpts, dict, NoneType] = None, tooltip_opts: Union[pyecharts.options.global_options.TooltipOpts, dict, NoneType] = None, itemstyle_opts: Union[pyecharts.options.series_options.ItemStyleOpts, dict, NoneType] = None, encode: Union[str, pyecharts.commons.utils.JsCode, dict, NoneType] = None)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from pyecharts.charts.chart.RectChart:
#      |
#      |  __init__(self, init_opts: Union[pyecharts.options.global_options.InitOpts, dict] = <pyecharts.options.global_options.InitOpts object at 0x000001E76D61D3C8>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  add_xaxis(self, xaxis_data: Sequence)
#      |
#      |  extend_axis(self, xaxis_data: Sequence = None, xaxis: Union[pyecharts.options.global_options.AxisOpts, dict, NoneType] = None, yaxis: Union[pyecharts.options.global_options.AxisOpts, dict, NoneType] = None)
#      |
#      |  overlap(self, chart: pyecharts.charts.base.Base)
#      |
#      |  reversal_axis(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from pyecharts.charts.chart.Chart:
#      |
#      |  add_dataset(self, source: Union[Sequence, str, pyecharts.commons.utils.JsCode] = None, dimensions: Union[Sequence, NoneType] = None, source_header: Union[bool, NoneType] = None)
#      |
#      |  set_colors(self, colors: Sequence[str])
#      |
#      |  set_global_opts(self, title_opts: Union[pyecharts.options.global_options.TitleOpts, dict] = <pyecharts.options.global_options.TitleOpts object at 0x000001E76D616588>, legend_opts: Union[pyecharts.options.global_options.LegendOpts, dict] = <pyecharts.options.global_options.LegendOpts object at 0x000001E76D61D2C8>, tooltip_opts: Union[pyecharts.options.global_options.TooltipOpts, dict, NoneType] = None, toolbox_opts: Union[pyecharts.options.global_options.ToolboxOpts, dict] = None, brush_opts: Union[pyecharts.options.global_options.BrushOpts, dict, NoneType] = None, xaxis_opts: Union[pyecharts.options.global_options.AxisOpts, dict, NoneType] = None, yaxis_opts: Union[pyecharts.options.global_options.AxisOpts, dict, NoneType] = None, visualmap_opts: Union[pyecharts.options.global_options.VisualMapOpts, dict, Sequence[Union[pyecharts.options.global_options.VisualMapOpts, dict]], NoneType] = None, datazoom_opts: Union[pyecharts.options.global_options.DataZoomOpts, dict, Sequence[Union[pyecharts.options.global_options.DataZoomOpts, dict]], NoneType] = None, graphic_opts: Union[pyecharts.options.charts_options.BaseGraphic, dict, Sequence[Union[pyecharts.options.charts_options.BaseGraphic, dict]], NoneType] = None, axispointer_opts: Union[pyecharts.options.global_options.AxisPointerOpts, dict, NoneType] = None)
#      |
#      |  set_series_opts(self, label_opts: Union[pyecharts.options.series_options.LabelOpts, dict, NoneType] = None, linestyle_opts: Union[pyecharts.options.series_options.LineStyleOpts, dict, NoneType] = None, splitline_opts: Union[pyecharts.options.series_options.SplitLineOpts, dict, NoneType] = None, areastyle_opts: Union[pyecharts.options.series_options.AreaStyleOpts, dict, NoneType] = None, axisline_opts: Union[pyecharts.options.global_options.AxisLineOpts, dict, NoneType] = None, markpoint_opts: Union[pyecharts.options.series_options.MarkPointOpts, dict, NoneType] = None, markline_opts: Union[pyecharts.options.series_options.MarkLineOpts, dict, NoneType] = None, markarea_opts: Union[pyecharts.options.series_options.MarkAreaOpts, dict, NoneType] = None, effect_opts: Union[pyecharts.options.series_options.EffectOpts, dict, NoneType] = <pyecharts.options.series_options.EffectOpts object at 0x000001E76D616448>, tooltip_opts: Union[pyecharts.options.global_options.TooltipOpts, dict, NoneType] = None, itemstyle_opts: Union[pyecharts.options.series_options.ItemStyleOpts, dict, NoneType] = None, **kwargs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from pyecharts.charts.base.Base:
#      |
#      |  dump_options(self) -> str
#      |
#      |  dump_options_with_quotes(self) -> str
#      |
#      |  get_options(self) -> dict
#      |
#      |  render(self, path: str = 'render.html', template_name: str = 'simple_chart.html', env: Union[jinja2.environment.Environment, NoneType] = None, **kwargs) -> str
#      |
#      |  render_embed(self, template_name: str = 'simple_chart.html', env: Union[jinja2.environment.Environment, NoneType] = None, **kwargs) -> str
#      |
#      |  render_notebook(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from pyecharts.charts.mixins.ChartMixin:
#      |
#      |  add_js_funcs(self, *fns)
#      |
#      |  load_javascript(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from pyecharts.charts.mixins.ChartMixin:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FILE
#     c:\users\ligong\anaconda3\lib\site-packages\pyecharts\charts\basic_charts\bar.py

# %% [markdown]
# 【例8-3】绘制水平直方图。

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# %matplotlib inline
bar = Bar()
bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
bar.set_global_opts(title_opts=opts.TitleOpts(title="货品销售情况",subtitle = "A和B公司"),toolbox_opts = opts.ToolboxOpts(is_show = True))
bar.set_series_opts(label_opts=opts.LabelOpts(position = "right"))
bar.reversal_axis()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5817c1c8021d43a2b8b1973b5b571f90" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5817c1c8021d43a2b8b1973b5b571f90 = echarts.init(
#                     document.getElementById('5817c1c8021d43a2b8b1973b5b571f90'), 'white', {renderer: 'canvas'});
#                 var option_5817c1c8021d43a2b8b1973b5b571f90 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u8d27\u54c1\u9500\u552e\u60c5\u51b5",
#             "subtext": "A\u548cB\u516c\u53f8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "xAxisIndex": false,
#                 "yAxisIndex": false,
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             },
#             "brush": {
#                 "icon": {},
#                 "title": {
#                     "rect": "\u77e9\u5f62\u9009\u62e9",
#                     "polygon": "\u5708\u9009",
#                     "lineX": "\u6a2a\u5411\u9009\u62e9",
#                     "lineY": "\

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
help(opts.global_options.LabelOpts)
# Out:
# Help on class LabelOpts in module pyecharts.options.series_options:
#
# class LabelOpts(BasicOpts)
#  |  LabelOpts(is_show: bool = True, position: Union[str, Sequence] = 'top', color: Union[str, NoneType] = None, distance: Union[int, float, Sequence, NoneType] = None, font_size: Union[int, float, NoneType] = None, font_style: Union[str, NoneType] = None, font_weight: Union[str, NoneType] = None, font_family: Union[str, NoneType] = None, rotate: Union[int, float, NoneType] = None, margin: Union[int, float, NoneType] = 8, interval: Union[int, float, str, NoneType] = None, horizontal_align: Union[str, NoneType] = None, vertical_align: Union[str, NoneType] = None, formatter: Union[str, pyecharts.commons.utils.JsCode, NoneType] = None, background_color: Union[str, NoneType] = None, border_color: Union[str, NoneType] = None, border_width: Union[int, float, NoneType] = None, border_radius: Union[int, float, NoneType] = None, rich: Union[dict, NoneType] = None)
#  |
#  |  Method resolution order:
#  |      LabelOpts
#  |      BasicOpts
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, is_show: bool = True, position: Union[str, Sequence] = 'top', color: Union[str, NoneType] = None, distance: Union[int, float, Sequence, NoneType] = None, font_size: Union[int, float, NoneType] = None, font_style: Union[str, NoneType] = None, font_weight: Union[str, NoneType] = None, font_family: Union[str, NoneType] = None, rotate: Union[int, float, NoneType] = None, margin: Union[int, float, NoneType] = 8, interval: Union[int, float, str, NoneType] = None, horizontal_align: Union[str, NoneType] = None, vertical_align: Union[str, NoneType] = None, formatter: Union[str, pyecharts.commons.utils.JsCode, NoneType] = None, background_color: Union[str, NoneType] = None, border_color: Union[str, NoneType] = None, border_width: Union[int, float, NoneType] = None, border_radius: Union[int, float, NoneType] = None, rich: Union[dict, NoneType] = None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BasicOpts:
#  |
#  |  get(self, key: str) -> Any
#  |
#  |  update(self, **kwargs)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BasicOpts:
#  |
#  |  opts

# %% [markdown]
# 【例8-4】饼图绘制。

# %%
# from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
L1=['教授','副教授','讲师','助教','其他']
num  = [20,30,10,12,8]
c = Pie()
c.add("", [list(z) for z in zip(L1,num)])
c.set_global_opts(title_opts=opts.TitleOpts(title="Pie-职称类别比例"))
c.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8604e678e146431896229ff0ca079717" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8604e678e146431896229ff0ca079717 = echarts.init(
#                     document.getElementById('8604e678e146431896229ff0ca079717'), 'white', {renderer: 'canvas'});
#                 var option_8604e678e146431896229ff0ca079717 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6559\u6388",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u526f\u6559\u6388",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8bb2\u5e08",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u52a9\u6559",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 8
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6559\u6388",
#                 "\u526f\u6559\u6388",
#                 "\u8bb2\u5e08",
#                 "\u52a9\u6559",
#                 "\u5176\u4ed6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u804c\u79f0\u7c7b\u522b\u6bd4\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8604e678e146431896229ff0ca079717.setOption(option_8604e678e146431896229ff0ca079717);
#         });
#     </script>

# %% [markdown]
# 【例8-5】圆形饼图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c = Pie()
c.add("",[list(z) for z in zip(wd, num)],radius = ["40%", "75%"])   
# 圆环的粗细和大小
c.set_global_opts( title_opts=opts.TitleOpts(title="Pie-Radius"),legend_opts=opts.LegendOpts( orient="vertical", pos_top="5%", pos_left="2%" ))
c .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8d4b430bb422402b98d19538c367a764" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8d4b430bb422402b98d19538c367a764 = echarts.init(
#                     document.getElementById('8d4b430bb422402b98d19538c367a764'), 'white', {renderer: 'canvas'});
#                 var option_8d4b430bb422402b98d19538c367a764 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6559\u6388",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u526f\u6559\u6388",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8bb2\u5e08",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u52a9\u6559",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 8
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6559\u6388",
#                 "\u526f\u6559\u6388",
#                 "\u8bb2\u5e08",
#                 "\u52a9\u6559",
#                 "\u5176\u4ed6"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "5%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-Radius",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8d4b430bb422402b98d19538c367a764.setOption(option_8d4b430bb422402b98d19538c367a764);
#         });
#     </script>

# %% [markdown]
# 【例8-6】圆形饼图中的rich参数应用。

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c = Pie()
c.add("",[list(z) for z in zip(wd, num)],radius=["40%", "55%"],
       label_opts=opts.LabelOpts(position="outside",
       formatter="{a|{a}}{abg|}\n{hr|}\n{b|{b}:}{c}  {per|{d}%} ",
       background_color="#eee",border_color="#aaa",
       border_width=1,border_radius=4,
       rich={"a": {"color": "#999", "lineHeight": 22, "align": 
"center"},"abg": {"backgroundColor": "#e3e3e3","width": "100%", "align": "right", "height": 22,"borderRadius": [4, 4, 0, 0],}, "hr": {"borderColor": "#aaa", "width": "100%",
"borderWidth": 0.5, "height": 0,}, "b": {"fontSize": 16, "lineHeight": 33},"per": {"color": "#eee",
"backgroundColor": "#334455",                        "padding": [2, 4],"borderRadius": 2,} } ))
c.set_global_opts(title_opts=opts.TitleOpts(title="Pie-富文本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ed8ee9a6aeaa4eb3b53d7a6e85ceb243" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ed8ee9a6aeaa4eb3b53d7a6e85ceb243 = echarts.init(
#                     document.getElementById('ed8ee9a6aeaa4eb3b53d7a6e85ceb243'), 'white', {renderer: 'canvas'});
#                 var option_ed8ee9a6aeaa4eb3b53d7a6e85ceb243 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6559\u6388",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u526f\u6559\u6388",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8bb2\u5e08",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u52a9\u6559",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 8
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{a|{a}}{abg|}\n{hr|}\n{b|{b}:}{c}  {per|{d}%} ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6559\u6388",
#                 "\u526f\u6559\u6388",
#                 "\u8bb2\u5e08",
#                 "\u52a9\u6559",
#                 "\u5176\u4ed6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u5bcc\u6587\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ed8ee9a6aeaa4eb3b53d7a6e85ceb243.setOption(option_ed8ee9a6aeaa4eb3b53d7a6e85ceb243);
#         });
#     </script>

# %% [markdown]
# 【例8-7】玫瑰图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
data1 = [45,86,39,52,68]
data2 = [67,36,64,89,123]
labels = ['电脑','手机','彩电','冰箱','洗衣机']
c = Pie()
c.add("",[list(z) for z in zip(labels, data1)],radius=["35%", "70%"],center=[180,220],rosetype='radius')
c.add("",[list(z) for z in zip(labels, data2)],radius=["35%", "70%"],center=[550,220],rosetype='area')
c.set_global_opts(title_opts=opts.TitleOpts(title="玫瑰图"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="38d24cd7c4754f108835e064092e6c41" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_38d24cd7c4754f108835e064092e6c41 = echarts.init(
#                     document.getElementById('38d24cd7c4754f108835e064092e6c41'), 'white', {renderer: 'canvas'});
#                 var option_38d24cd7c4754f108835e064092e6c41 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7535\u8111",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u624b\u673a",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u5f69\u7535",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u51b0\u7bb1",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u6d17\u8863\u673a",
#                     "value": 68
#                 }
#             ],
#             "radius": [
#                 "35%",
#                 "70%"
#             ],
#             "center": [
#                 180,
#                 220
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7535\u8111",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u624b\u673a",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5f69\u7535",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u51b0\u7bb1",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u6d17\u8863\u673a",
#                     "value": 123
#                 }
#             ],
#             "radius": [
#                 "35%",
#                 "70%"
#             ],
#             "center": [
#                 550,
#                 220
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7535\u8111",
#                 "\u624b\u673a",
#                 "\u5f69\u7535",
#                 "\u51b0\u7bb1",
#                 "\u6d17\u8863\u673a"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u73ab\u7470\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_38d24cd7c4754f108835e064092e6c41.setOption(option_38d24cd7c4754f108835e064092e6c41);
#         });
#     </script>

# %% [markdown]
# 【例8-8】漏斗图绘制。

# %%
from pyecharts.charts import Funnel
from pyecharts import options as opts
# %matplotlib inline
data = [45,86,39,52,68]
labels = ['电脑','手机','彩电','冰箱','洗衣机']
wf = Funnel()
wf.add('电器销量图',[list(z) for z in zip(labels, data)], is_selected= True)
wf.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0c3a8fe32374417182e867ed59fb4f57" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0c3a8fe32374417182e867ed59fb4f57 = echarts.init(
#                     document.getElementById('0c3a8fe32374417182e867ed59fb4f57'), 'white', {renderer: 'canvas'});
#                 var option_0c3a8fe32374417182e867ed59fb4f57 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u7535\u5668\u9500\u91cf\u56fe",
#             "data": [
#                 {
#                     "name": "\u7535\u8111",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u624b\u673a",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u5f69\u7535",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u51b0\u7bb1",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u6d17\u8863\u673a",
#                     "value": 68
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u51b0\u7bb1",
#                 "\u7535\u8111",
#                 "\u624b\u673a",
#                 "\u5f69\u7535",
#                 "\u6d17\u8863\u673a"
#             ],
#             "selected": {
#                 "\u7535\u8111": true,
#                 "\u624b\u673a": true,
#                 "\u5f69\u7535": true,
#                 "\u51b0\u7bb1": true,
#                 "\u6d17\u8863\u673a": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_0c3a8fe32374417182e867ed59fb4f57.setOption(option_0c3a8fe32374417182e867ed59fb4f57);
#         });
#     </script>

# %% [markdown]
# 【例8-9】散点图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter
week = ["周一", "周二", "周三", "周四", "周五", "周六", "周日"]
c = Scatter()
c.add_xaxis(week)
#c.add_xaxis(Faker.choose())
#c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家A", [81,65,48,32,68,92,87])
c.set_global_opts(title_opts=opts.TitleOpts(title="Scatter-一周的销售额（万元）"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4d7d3491efd341128d86a988b4e3cada" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4d7d3491efd341128d86a988b4e3cada = echarts.init(
#                     document.getElementById('4d7d3491efd341128d86a988b4e3cada'), 'white', {renderer: 'canvas'});
#                 var option_4d7d3491efd341128d86a988b4e3cada = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     81
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     65
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     48
#                 ],
#                 [
#                     "\u5468\u56db",
#                     32
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     68
#                 ],
#                 [
#                     "\u5468\u516d",
#                     92
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     87
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u4e00\u5468\u7684\u9500\u552e\u989d\uff08\u4e07\u5143\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4d7d3491efd341128d86a988b4e3cada.setOption(option_4d7d3491efd341128d86a988b4e3cada);
#         });
#     </script>

# %% [markdown]
# 例8-10】K线图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Kline
data = [[2320.26, 2320.26, 2287.3, 2362.94],
        [2300, 2291.3, 2288.26, 2308.38],
        [2295.35, 2346.5, 2295.35, 2345.92],
        [2347.22, 2358.98, 2337.35, 2363.8], 
        [2360.75, 2382.48, 2347.89, 2383.76],
        [2383.43, 2385.42, 2371.23, 2391.82],
        [2377.41, 2419.02, 2369.57, 2421.15],
        [2425.92, 2428.15, 2417.58, 2440.38],
        [2411, 2433.13, 2403.3, 2437.42],
        [2432.68, 2334.48, 2427.7, 2441.73],
        [2430.69, 2418.53, 2394.22, 2433.89],
        [2416.62, 2432.4, 2414.4, 2443.03],  
        [2441.91, 2421.56, 2418.43, 2444.8],
        [2420.26, 2382.91, 2373.53, 2427.07],   
        [2383.49, 2397.18, 2370.61, 2397.94],
        [2378.82, 2325.95, 2309.17, 2378.82], 
        [2322.94, 2314.16, 2308.76, 2330.88],
        [2320.62, 2325.82, 2315.01, 2338.78],  
        [2313.74, 2293.34, 2289.89, 2340.71],
        [2297.77, 2313.22, 2292.03, 2324.63], 
        [2322.32, 2365.59, 2308.92, 2366.16],
        [2364.54, 2359.51, 2330.86, 2369.65], 
        [2332.08, 2273.4, 2259.25, 2333.54], 
        [2274.81, 2326.31, 2270.1, 2328.14], 
        [2333.61, 2347.18, 2321.6, 2351.44], 
        [2340.44, 2324.29, 2304.27, 2352.02], 
        [2326.42, 2318.61, 2314.59, 2333.67],
        [2314.68, 2310.59, 2296.58, 2320.96], 
        [2309.16, 2286.6, 2264.83, 2333.29], 
        [2282.17, 2263.97, 2253.25, 2286.33], 
        [2255.77, 2270.28, 2253.31, 2276.22] ]
c = Kline()
c.add_xaxis(["2019/7/{}".format(i + 1) for i in range(31)])
c.add_yaxis("2019年7月份K线图", data)
c.set_global_opts(yaxis_opts=opts.AxisOpts(is_scale=True),
            xaxis_opts=opts.AxisOpts(is_scale=True),
            title_opts=opts.TitleOpts(title="Kline-基本示例"),)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="55c44e842b234fa080f5d5621a5ee946" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_55c44e842b234fa080f5d5621a5ee946 = echarts.init(
#                     document.getElementById('55c44e842b234fa080f5d5621a5ee946'), 'white', {renderer: 'canvas'});
#                 var option_55c44e842b234fa080f5d5621a5ee946 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "candlestick",
#             "name": "2019\u5e747\u6708\u4efdK\u7ebf\u56fe",
#             "data": [
#                 [
#                     2320.26,
#                     2320.26,
#                     2287.3,
#                     2362.94
#                 ],
#                 [
#                     2300,
#                     2291.3,
#                     2288.26,
#                     2308.38
#                 ],
#                 [
#                     2295.35,
#                     2346.5,
#                     2295.35,
#                     2345.92
#                 ],
#                 [
#                     2347.22,
#                     2358.98,
#                     2337.35,
#                     2363.8
#                 ],
#                 [
#                     2360.75,
#                     2382.48,
#                     2347.89,
#                     2383.76
#                 ],
#                 [
#                     2383.43,
#                     2385.42,
#                     2371.23,
#                     2391.82
#                 ],
#                 [
#                     2377.41,
#                     2419.02,
#                     2369.57,
#                     2421.15
#                 ],
#                 [
#                     2425.92,
#                     2428.15,
#                     2417.58,
#                     2440.38
#                 ],
#                 [
#                     2411,
#                     2433.13,
#                     2403.3,
#                     2437.42
#                 ],
#                 [
#                     2432.68,
#                     2334.48,
#                     2427.7,
#                     2441.73
#                 ],
#                 [
#                     2430.69,
#                     2418.53,
#                     2394.22,
#                     2433.89
#                 ],
#                 [
#                     2416.62,
#                     2432.4,
#                     2414.4,
#                     2443.03
#                 ],
#                 [
#                     2441.91,
#                     2421.56,
#                     2418.43,
#                     2444.8
#                 ],
#                 [
#                     2420.26,
#                     2382.91,
#                     2373.53,
#                     2427.07
#                 ],
#                 [
#                     2383.49,
#                     2397.18,
#                     2370.61,
#                     2397.94
#                 ],
#                 [
#                     2378.82,
#                     2325.95,
#                     2309.17,
#                     2378.82
#                 ],
#                 [
#                     2322.94,
#                     2314.16,
#                     2308.76,
#                     2330.88
#                 ],
#                 [
#                     2320.62,
#                     2325.82,
#                     2315.01,
#                     2338.78
#                 ],
#                 [
#                     2313.74,
#                     2293.34,
#                     2289.89,
#                     2340.71
#                 ],
#                 [
#                     2297.77,
#                     2313.22,
#                     2292.03,
#                     2324.63
#                 ],
#                 [
#                     2322.32,
#                     2365.59,
#                     2308.92,
#                     2366.16
#                 ],
#                 [
#                     2364.54,
#                     2359.51,
#                     2330.86,
#                     2369.65
#                 ],
#                 [
#                     2332.08,
#                     2273.4,
#                     2259.25,
#                     2333.54
#                 ],
#                 [
#                     2274.81,
#                     2326.31,
#                     2270.1,
#                     2328.14
#                 ],
#                 [
#                     2333.61,
#                     2347.18,
#                     2321.6,
#                     2351.44
#                 ],
#                 [
#                     2340.44,
#                     2324.29,
#                     2304.27,
#                     2352.02
#                 ],
#                 [
#                     2326.42,
#                     2318.61,
#                     2314.59,
#                     2333.67
#                 ],
#                 [
#                     2314.68,
#                     2310.59,
#                     2296.58,
#                     2320.96
#                 ],
#                 [
#                     2309.16,
#                     2286.6,
#                     2264.83,
#                     2333.29
#                 ],
#                 [
#                     2282.17,
#                     2263.97,
#                     2253.25,
#                     2286.33
#                 ],
#                 [
#                     2255.77,
#                     2270.28,
#                     2253.31,
#                     2276.22
#                 ]
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2019\u5e747\u6708\u4efdK\u7ebf\u56fe"
#             ],
#             "selected": {
#                 "2019\u5e747\u6708\u4efdK\u7ebf\u56fe": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2019/7/1",
#                 "2019/7/2",
#                 "2019/7/3",
#                 "2019/7/4",
#                 "2019/7/5",
#                 "2019/7/6",
#                 "2019/7/7",
#                 "2019/7/8",
#                 "2019/7/9",
#                 "2019/7/10",
#                 "2019/7/11",
#                 "2019/7/12",
#                 "2019/7/13",
#                 "2019/7/14",
#                 "2019/7/15",
#                 "2019/7/16",
#                 "2019/7

# %% [markdown]
# 【例8-11】仪表盘图绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page
c = Gauge()
c.add("业务指标",[("完成率", 55.5)],axisline_opts=opts.AxisLineOpts(
linestyle_opts=opts.LineStyleOpts(color=[(0.3, "#67e0e3"),
 (0.7, "#37a2da"), (1, "#fd666d")], width=30)))
c.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-不同颜色"),
 legend_opts=opts.LegendOpts(is_show=False)) 
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="86e85b8767334f45b3ce4f47203781f2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_86e85b8767334f45b3ce4f47203781f2 = echarts.init(
#                     document.getElementById('86e85b8767334f45b3ce4f47203781f2'), 'white', {renderer: 'canvas'});
#                 var option_86e85b8767334f45b3ce4f47203781f2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "color": "#333",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "backgroundColor": "transparent",
#                 "borderColor": "transparent",
#                 "borderWidth": 0,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 0,
#                 "borderColor": "transparent",
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "formatter": "{value}%",
#                 "color": "auto",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 55.5
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             },
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Gauge-\u4e0d\u540c\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_86e85b8767334f45b3ce4f47203781f2.setOption(option_86e85b8767334f45b3ce4f47203781f2);
#         });
#     </script>

# %% [markdown]
# 【例8-12】词云绘制。

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType
words = [
    ("牛肉面", 7800),("黄河", 6181),
    ("《读者》杂志", 4386), ("甜胚子", 3055),
    ("甘肃省博物馆", 2055),("莫高窟", 8067),("兰州大学", 4244),
    ("西北师范大学", 1868),("中山桥", 3484),
    ("月牙泉", 1112),("五泉山", 980),
    ("五彩丹霞", 865),("黄河母亲", 847),("崆峒山",678),
    ("羊皮筏子", 1582),("兴隆山",868),
    ("兰州交通大学", 1555),("白塔山", 2550),("五泉山", 2550)]
c = WordCloud()
c.add("", words, word_size_range=[20, 80])
c.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="6fa0ca91ae7b43fb81d7b7c9e6afb7d5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_6fa0ca91ae7b43fb81d7b7c9e6afb7d5 = echarts.init(
#                     document.getElementById('6fa0ca91ae7b43fb81d7b7c9e6afb7d5'), 'white', {renderer: 'canvas'});
#                 var option_6fa0ca91ae7b43fb81d7b7c9e6afb7d5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 80
#             ],
#             "data": [
#                 {
#                     "name": "\u725b\u8089\u9762",
#                     "value": 7800,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,115,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u6cb3",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,79,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u300a\u8bfb\u8005\u300b\u6742\u5fd7",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,117,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u751c\u80da\u5b50",
#                     "value": 3055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,77,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7518\u8083\u7701\u535a\u7269\u9986",
#                     "value": 2055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,30,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u83ab\u9ad8\u7a9f",
#                     "value": 8067,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,14,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5170\u5dde\u5927\u5b66",
#                     "value": 4244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,21,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u897f\u5317\u5e08\u8303\u5927\u5b66",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,20,112)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u5c71\u6865",
#                     "value": 3484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,142,10)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u7259\u6cc9",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,104,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u6cc9\u5c71",
#                     "value": 980,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,126,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u5f69\u4e39\u971e",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,154,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u6cb3\u6bcd\u4eb2",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,60,18)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5d06\u5cd2\u5c71",
#                     "value": 678,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,47,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f8a\u76ae\u7b4f\u5b50",
#                     "value": 1582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,82,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5174\u9686\u5c71",
#                     "value": 868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,12,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5170\u5dde\u4ea4\u901a\u5927\u5b66",
#                     "value": 1555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,95,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u767d\u5854\u5c71",
#                     "value": 2550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,90,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u6cc9\u5c71",
#                     "value": 2550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,70,23)"
#                         }
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysSh

# %% [markdown]
# 【例8-13】在指定地图上的城市标示某天最高温度。

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
temperature=[30,31,27,29,18]
loc = ['兰州市','天水市','白银市','武威市','甘南藏族自治州']
c =  Map()
c.add("甘肃省", [list(z) for z in zip(loc, temperature)], "甘肃",is_roam=True) 
# is_roam是否开启鼠标缩放和平移漫游
c .set_global_opts(title_opts=opts.TitleOpts(title="甘肃省部分城市最高气温"))
c.render("APP类型.html")
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '甘肃':'https://assets.pyecharts.org/assets/maps/gansu'
#         }
#     });
# </script>
#
#         <div id="a9f10c13e6604bcbb600b7efedb458eb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '甘肃'], function(echarts) {
#                 var chart_a9f10c13e6604bcbb600b7efedb458eb = echarts.init(
#                     document.getElementById('a9f10c13e6604bcbb600b7efedb458eb'), 'white', {renderer: 'canvas'});
#                 var option_a9f10c13e6604bcbb600b7efedb458eb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u7518\u8083\u7701",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u7518\u8083",
#             "data": [
#                 {
#                     "name": "\u5170\u5dde\u5e02",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5929\u6c34\u5e02",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u767d\u94f6\u5e02",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u6b66\u5a01\u5e02",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u7518\u5357\u85cf\u65cf\u81ea\u6cbb\u5dde",
#                     "value": 18
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7518\u8083\u7701"
#             ],
#             "selected": {
#                 "\u7518\u8083\u7701": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7518\u8083\u7701\u90e8\u5206\u57ce\u5e02\u6700\u9ad8\u6c14\u6e29",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a9f10c13e6604bcbb600b7efedb458eb.setOption(option_a9f10c13e6604bcbb600b7efedb458eb);
#         });
#     </script>

# %% [markdown]
# 【例8-14】组合图表上下布局。

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line,Scatter
A = ["小米", "三星", "华为", "苹果", "魅族", "VIVO", "OPPO"]
CA = [100,125,87,90,78,98,118]
B = ["草莓", "芒果", "葡萄", "雪梨", "西瓜", "柠檬", "车厘子"]
CB = [78,95,120,102,88,108,98]
bar = Bar()
bar.add_xaxis(A)
bar.add_yaxis("商家A",CA)
bar.add_yaxis("商家B", CB)
bar.set_global_opts(title_opts=opts.TitleOpts(title="Grid-Bar"))
bar.render_notebook()
line=Line()
line.add_xaxis(B)
line.add_yaxis("商家A", CA)
line.add_yaxis("商家B", CB)
line.set_global_opts(title_opts=opts.TitleOpts(title="Grid-Line", pos_top="48%"),
legend_opts=opts.LegendOpts(pos_top="48%"))
line.render_notebook()
grid = Grid()
grid.add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))
grid.add(line, grid_opts=opts.GridOpts(pos_top="60%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="08356dd632ff4c29a87f3077623f31a7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_08356dd632ff4c29a87f3077623f31a7 = echarts.init(
#                     document.getElementById('08356dd632ff4c29a87f3077623f31a7'), 'white', {renderer: 'canvas'});
#                 var option_08356dd632ff4c29a87f3077623f31a7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 100,
#                 125,
#                 87,
#                 90,
#                 78,
#                 98,
#                 118
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 78,
#                 95,
#                 120,
#                 102,
#                 88,
#                 108,
#                 98
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     100
#                 ],
#                 [
#                     "\u8292\u679c",
#                     125
#                 ],
#                 [
#                     "\u8461\u8404",
#                     87
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     90
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     78
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     98
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     118
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     78
#                 ],
#                 [
#                     "\u8292\u679c",
#                     95
#                 ],
#                 [
#                     "\u8461\u8404",
#                     120
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     102
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     88
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     108
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     98
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "top": "48%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter3D
from pyecharts.faker import Faker
import random
data = [(random.randint( 0, 100), random.randint( 0, 100), random.randint( 0, 100))
for _ in range(80)]
scatter3D = Scatter3D()
scatter3D.add( "", data)
scatter3D.set_global_opts(
title_opts=opts.TitleOpts( "Scatter3D-基本示例"),
visualmap_opts=opts.VisualMapOpts(range_color=Faker.visual_color))
scatter3D.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="34fc144f65a94ffb8d20628e28d59aa5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_34fc144f65a94ffb8d20628e28d59aa5 = echarts.init(
#                     document.getElementById('34fc144f65a94ffb8d20628e28d59aa5'), 'white', {renderer: 'canvas'});
#                 var option_34fc144f65a94ffb8d20628e28d59aa5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "data": [
#                 [
#                     94,
#                     63,
#                     44
#                 ],
#                 [
#                     19,
#                     61,
#                     6
#                 ],
#                 [
#                     46,
#                     30,
#                     80
#                 ],
#                 [
#                     41,
#                     14,
#                     29
#                 ],
#                 [
#                     48,
#                     59,
#                     68
#                 ],
#                 [
#                     21,
#                     0,
#                     11
#                 ],
#                 [
#                     9,
#                     3,
#                     53
#                 ],
#                 [
#                     67,
#                     0,
#                     79
#                 ],
#                 [
#                     10,
#                     40,
#                     59
#                 ],
#                 [
#                     78,
#                     0,
#                     67
#                 ],
#                 [
#                     2,
#                     4,
#                     45
#                 ],
#                 [
#                     0,
#                     32,
#                     40
#                 ],
#                 [
#                     76,
#                     94,
#                     42
#                 ],
#                 [
#                     55,
#                     98,
#                     6
#                 ],
#                 [
#                     30,
#                     69,
#                     28
#                 ],
#                 [
#                     27,
#                     35,
#                     21
#                 ],
#                 [
#                     95,
#                     21,
#                     15
#                 ],
#                 [
#                     19,
#                     100,
#                     78
#                 ],
#                 [
#                     54,
#                     60,
#                     46
#                 ],
#                 [
#                     70,
#                     73,
#                     19
#                 ],
#                 [
#                     22,
#                     17,
#                     57
#                 ],
#                 [
#                     8,
#                     43,
#                     22
#                 ],
#                 [
#                     75,
#                     80,
#                     99
#                 ],
#                 [
#                     92,
#                     96,
#                     70
#                 ],
#                 [
#                     66,
#                     5,
#                     86
#                 ],
#                 [
#                     90,
#                     0,
#                     83
#                 ],
#                 [
#                     54,
#                     75,
#                     12
#                 ],
#                 [
#                     41,
#                     97,
#                     99
#                 ],
#                 [
#                     100,
#                     61,
#                     22
#                 ],
#                 [
#                     12,
#                     46,
#                     37
#                 ],
#                 [
#                     17,
#                     34,
#                     47
#                 ],
#                 [
#                     14,
#                     29,
#                     55
#                 ],
#                 [
#                     19,
#                     4,
#                     100
#                 ],
#                 [
#                     59,
#                     21,
#                     60
#                 ],
#                 [
#                     47,
#                     27,
#                     88
#                 ],
#                 [
#                     23,
#                     72,
#                     23
#                 ],
#                 [
#                     70,
#                     37,
#                     41
#                 ],
#                 [
#                     48,
#                     2,
#                     41
#                 ],
#                 [
#                     45,
#                     30,
#                     19
#                 ],
#                 [
#                     21,
#                     76,
#                     30
#                 ],
#                 [
#                     37,
#                     18,
#                     8
#                 ],
#                 [
#                     56,
#                     20,
#                     51
#                 ],
#                 [
#                     90,
#                     46,
#                     18
#                 ],
#                 [
#                     55,
#                     20,
#                     46
#                 ],
#                 [
#                     28,
#                     16,
#                     55
#                 ],
#                 [
#                     94,
#                     30,
#                     86
#                 ],
#                 [
#                     92,
#                     76,
#                     92
#                 ],
#                 [
#                     32,
#                     98,
#                     20
#                 ],
#                 [
#                     6,
#                     37,
#                     47
#                 ],
#                 [
#                     16,
#                     70,
#                     75
#                 ],
#                 [
#                     82,
#                     8,
#                     23
#                 ],
#                 [
#                     47,
#                     100,
#                     80
#                 ],
#                 [
#                     67,
#                     37,
#                     4
#                 ],
#                 [
#                     82,
#                     14,
#                     29
#                 ],
#                 [
#                     30,
#                     42,
#                     17
#                 ],
#                 [
#                     36,
#                     98,
#                     33
#                 ],
#                 [
#                     72,
#                     40,
#                     0
#                 ],
#                 [
#                     77,
#                     35,
#                     77
#                 ],
#                 [
#                     98,
#                     42,
#                     37
#                 ],
#                 [
#                     76,
#                     98,
#                     97
#                 ],
#                 [
#                     41,
#                     30,
#                     9

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
import random
province = [ '广东', '湖北', '湖南', '四川', '重庆', '黑龙江', '浙江', '山西', '河北', '安徽', '河南', '山东', '西藏']
data = [(i, random.randint( 50, 150)) for i in province]
_map = Map()
_map.add( "销售额", data, "china")
_map.set_global_opts(
title_opts=opts.TitleOpts(title= "Map-基本示例"),
legend_opts=opts.LegendOpts(is_show= False),
visualmap_opts=opts.VisualMapOpts(max_= 200, is_piecewise= True),
)
_map.render("map.html")
_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="c9f786dab4d549558c46be6f3f844fd7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c9f786dab4d549558c46be6f3f844fd7 = echarts.init(
#                     document.getElementById('c9f786dab4d549558c46be6f3f844fd7'), 'white', {renderer: 'canvas'});
#                 var option_c9f786dab4d549558c46be6f3f844fd7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u9500\u552e\u989d",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 102
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 114
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 112
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 57
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e\u989d"
#             ],
#             "selected": {
#                 "\u9500\u552e\u989d": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Map-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_c9f786dab4d549558c46be6f3f844fd7.setOption(option_c9f786dab4d549558c46be6f3f844fd7);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType
import random
province = [ '福州','厦门','漳州','泉州','莆田','三明','南平','龙岩','宁德']
data = [(i, random.randint(50, 150)) for i in province]

geo = (Geo()
        .add_schema(maptype="福建")
        .add("门店数", data,
            type_=ChartType.HEATMAP)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(),
            legend_opts=opts.LegendOpts(is_show=False),
            title_opts=opts.TitleOpts(title="Geo-福建热力地图"))
      )

geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '福建':'https://assets.pyecharts.org/assets/maps/fujian'
#         }
#     });
# </script>
#
#         <div id="a8872352df1f4930813b42f6d9ea77fe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '福建'], function(echarts) {
#                 var chart_a8872352df1f4930813b42f6d9ea77fe = echarts.init(
#                     document.getElementById('a8872352df1f4930813b42f6d9ea77fe'), 'white', {renderer: 'canvas'});
#                 var option_a8872352df1f4930813b42f6d9ea77fe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u95e8\u5e97\u6570",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u798f\u5dde",
#                     "value": [
#                         119.3,
#                         26.08,
#                         108
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         79
#                     ]
#                 },
#                 {
#                     "name": "\u6f33\u5dde",
#                     "value": [
#                         117.39,
#                         24.31,
#                         125
#                     ]
#                 },
#                 {
#                     "name": "\u6cc9\u5dde",
#                     "value": [
#                         118.58,
#                         24.93,
#                         124
#                     ]
#                 },
#                 {
#                     "name": "\u8386\u7530",
#                     "value": [
#                         119.01,
#                         24.26,
#                         104
#                     ]
#                 },
#                 {
#                     "name": "\u4e09\u660e",
#                     "value": [
#                         117.36,
#                         26.13,
#                         59
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u5e73",
#                     "value": [
#                         118.1,
#                         26.38,
#                         73
#                     ]
#                 },
#                 {
#                     "name": "\u9f99\u5ca9",
#                     "value": [
#                         117.01,
#                         25.06,
#                         111
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u5fb7",
#                     "value": [
#                         119.31,
#                         26.39,
#                         142
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u95e8\u5e97\u6570"
#             ],
#             "selected": {
#                 "\u95e8\u5e97\u6570": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Geo-\u798f\u5efa\u70ed\u529b\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "\u798f\u5efa",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_a8872352df1f4930813b42f6d9ea77fe.setOption(option_a8872352df1f4930813b42f6d9ea77fe);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Timeline
from pyecharts.globals import ThemeType
import random
# 示例数据
cate = [ 'Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
tl = Timeline()
for i in range(2015, 2021):
   bar = Bar()
   bar.add_xaxis(cate)
   bar.add_yaxis( "线上", [random.randint( 50, 150) for _ in cate])
   bar.add_yaxis( "门店", [random.randint( 100, 200) for _ in cate])
   bar.set_global_opts(title_opts=opts.TitleOpts( "手机品牌{}年营业额".format(i)))
   tl.add(bar, "{}年".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4b1bec7be46840c7af6764ca45d41e70" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4b1bec7be46840c7af6764ca45d41e70 = echarts.init(
#                     document.getElementById('4b1bec7be46840c7af6764ca45d41e70'), 'white', {renderer: 'canvas'});
#                 var option_4b1bec7be46840c7af6764ca45d41e70 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u7ebf\u4e0a",
#                 "legendHoverLink": true,
#                 "data": [
#                     61,
#                     140,
#                     63,
#                     89,
#                     123,
#                     108
#                 ],
#                 "showBackground": false,
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "\u95e8\u5e97",
#                 "legendHoverLink": true,
#                 "data": [
#                     160,
#                     185,
#                     196,
#                     108,
#                     188,
#                     200
#                 ],
#                 "showBackground": false,
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74",
#                 "2020\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "Apple",
#                     "Huawei",
#                     "Xiaomi",
#                     "Oppo",
#                     "Vivo",
#                     "Meizu"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\u7ebf\u4e0a",
#                         "\u95e8\u5e97"
#                     ],
#                     "selected": {
#                         "\u7ebf\u4e0a": true,
#                         "\u95e8\u5e97": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "\u7ebf\u4e0a",
#                     "legendHoverLink": true,
#                     "data": [
#                         53,
#                         139,
#                         128,
#                         55,
#                         96,
#                         129
#                     ],
#                     "showBackground": false,
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 },
#                 {
#                     "type": "bar",
#                     "name": "\u95e8\u5e97",
#                     "legendHoverLink": true,
#                     "data": [
#                         150,
#                         156,
#                         113,
#                         193,
#                         138,
#                         195
#                     ],
#                     "showBackground": false,
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "position": "top",
#                         "margin": 8
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     },
#                     "data": [
#                         "Apple",
#                         "Huawei",
#                         "Xiaomi",
#                         "Oppo",
#                         "Vivo",
#                         "Meizu"

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType, ThemeType
import requests

r = requests.get('https://echarts.apache.org/examples/data-gl/asset/data/flights.json')
data = r.json()

city = ['Beijing']
airports_code = []

geo = Geo(init_opts=opts.InitOpts(theme=ThemeType.DARK))
for i, airport in enumerate(data['airports']):
    if airport[1] in city:
        geo.add_coordinate(i, airport[3], airport[4])
        airports_code.append(i)

route = [(x, y) for _, x, y in data['routes'] if x in airports_code]


geo.add_schema(maptype="world",
                itemstyle_opts=opts.ItemStyleOpts())
geo.add("geo", route, 
        is_large = True,
        symbol_size=0,
        type_='lines',
        is_polyline=True,
        effect_opts=opts.EffectOpts(symbol='pin', symbol_size=1, trail_length=1, color="rgba(255,69,0,0.9)"),
        linestyle_opts=opts.LineStyleOpts(curve=0.2, width=0.2, color='rgb(245,245,245)',opacity=0.05)
       )
geo.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
geo.set_global_opts(title_opts=opts.TitleOpts(title="北京发出所有航线"),
                   legend_opts=opts.LegendOpts(is_show=False))

geo.render("geo.html")
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="51670523636c4aa7b408175c7cc60433" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_51670523636c4aa7b408175c7cc60433 = echarts.init(
#                     document.getElementById('51670523636c4aa7b408175c7cc60433'), 'dark', {renderer: 'canvas'});
#                 var option_51670523636c4aa7b408175c7cc60433 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "lines",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "zlevel": 2,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "rgba(255,69,0,0.9)",
#                 "symbol": "pin",
#                 "symbolSize": 1,
#                 "trailLength": 1
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": true,
#             "large": true,
#             "largeThreshold": 2000,
#             "symbolSize": 0,
#             "data": [
#                 {
#                     "name": "3268->3731",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->3478",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->1087",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->726",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->5219",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->5224",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->3786",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->1107",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->3273",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->1358",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->3278",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->4267",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->5460",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268->5215",
#                     "coords": [
#                         [
#                             116.584556,
#                             40.080111
#                         ],
#                         null
#                     ]
#                 },
#                 {
#                     "name": "3268
-0.133,5.865-5.598,6.398-6.998c0.533-1.397,0.668-3.732,0.668-3.732s0,0,2.199,1.867c2.199,1.865,2.332,4.6,2.998,7.73 s2.332,0.934,2.332-0.467c0-1.401,0.269-5.465-1-7.064c-1.265-1.6-3.73-3.465-3.73-5.265s1.199-3.732,1.199-3.732 c0.332,1.667,3.335,3.065,5.599,3.399C38.668,33.206,38.533,31.207,36.867,30.74z'}

symbol_list = list(symbol_dict.values())

geo=(Geo()
        .add_schema(maptype="china")
        .add(
            "",
            [("北京", 1), ("重庆", 2), ("长沙", 3), ("长春", 4), ("成都", 5), ("大连", 6), ("广州", 7), ("贵阳", 8),
            ("合肥", 9), ("杭州", 10), ("哈尔滨", 11), ("海口", 12), ("济南", 13), ("昆明", 14), ("柳州", 15), ("绵阳", 16),
            ("潞西市", 17), ("南宁", 18), ("南京", 19), ("沈阳", 20), ("三亚", 21), ("上海", 22), ("天津", 23), ("徐州", 24),
            ("义乌", 25), ("郑州", 26), ("张家界", 27)],
            type_=ChartType.EFFECT_SCATTER,
            color="#ffa022"
        )
        .add(
            "",
            [("揭阳", "北京"), ("揭阳", "重庆"), ("揭阳", "长沙"), ("揭阳", "长春"), ("揭阳", "成都"),
            ("揭阳", "大连"), ("揭阳", "广州"), ("揭阳", "贵阳"), ("揭阳", "合肥"), ("揭阳", "杭州"),
            ("揭阳", "哈尔滨"), ("揭阳", "海口"), ("揭阳", "济南"), ("揭阳", "昆明"), ("揭阳", "柳州"),
            ("揭阳", "绵阳"), ("揭阳", "潞西市"), ("揭阳", "南宁"), ("揭阳", "南京"), ("揭阳", "沈阳"),("揭阳", "三亚"),
            ("揭阳", "上海"), ("揭阳", "天津"), ("揭阳", "徐州"),("揭阳", "义乌"),("揭阳", "郑州"), ("揭阳", "张家界")],
            type_=ChartType.LINES,
            effect_opts=opts.EffectOpts(
                symbol=symbol_list[-1], symbol_size=15, color='#a6c84c', period=6, trail_length=0, is_show=True
            ),
            linestyle_opts=opts.LineStyleOpts(curve=0.2, color='#46bee9', width=1, opacity=0.5),
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="揭阳出发国内航线",  pos_left="center",
                        title_textstyle_opts=opts.TextStyleOpts(color='black',font_size=20, font_weight="bold"),
                        subtitle_textstyle_opts=opts.TextStyleOpts(color='black',font_size=15),item_gap=15))
        )
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="702a2e0d9a034ecf8bd45e7205457e99" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_702a2e0d9a034ecf8bd45e7205457e99 = echarts.init(
#                     document.getElementById('702a2e0d9a034ecf8bd45e7205457e99'), 'white', {renderer: 'canvas'});
#                 var option_702a2e0d9a034ecf8bd45e7205457e99 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#ffa022",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": [
#                         113,
#                         28.21,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6625",
#                     "value": [
#                         125.35,
#                         43.88,
#                         4
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         5
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u8fde",
#                     "value": [
#                         121.62,
#                         38.92,
#                         6
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         7
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u9633",
#                     "value": [
#                         106.71,
#                         26.57,
#                         8
#                     ]
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": [
#                         117.27,
#                         31.86,
#                         9
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         11
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u53e3",
#                     "value": [
#                         110.35,
#                         20.02,
#                         12
#                     ]
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": [
#                         117,
#                         36.65,
#                         13
#                     ]
#                 },
#                 {
#                     "name": "\u6606\u660e",
#                     "value": [
#                         102.73,
#                         25.04,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "\u67f3\u5dde",
#                     "value": [
#                         109.4,
#                         24.33,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "\u7ef5\u9633",
#                     "value": [
#                         104.73,
#                         31.48,
#                         16
#                     ]
#                 },
#                 {
#                     "name": "\u6f5e\u897f\u5e02",
#                     "value": [
#                         98.58,
#                         24.43,
#                         17
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u5b81",
#                     "value": [
#                         108.33,
#                         22.84,
#                         18
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         19
#                     ]
#                 },
#                 {
#                     "name": "\u6c88\u9633",
#                     "value": [
#                         123.38,
#                         41.8,
#                         20
#                     ]
#                 },
#                 {
#                     "name": "\u4e09\u4e9a",
#                     "value": [
#                         109.511909,
#                         18.252847,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u5f90\u5dde",
#                     "value": [
#                         117.2,
#                         34.26,
#                         24
#                     ]
#                 },
#                 {
#                     "name": "\u4e49\u4e4c",
#                     "value": [
#                         120.06,
#                         29.32,
#                         25
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         26
#                     ]
#                 },
#                 {
#                     "name": "\u5f20\u5bb6\u754c",
#                     "value": [
#                         110.479191,
#                         29.117096,
#                         27
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {

# %%
from pyecharts.charts import Calendar
from pyecharts import options as opts
import random
import datetime

# 示例数据
begin = datetime.date(2020, 1, 1)
end = datetime.date(2020, 12, 31)
data = [[str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
        for i in range((end - begin).days + 1)]

"""
日历图示例：
"""
calendar = (
        Calendar()
        .add("微信步数", data, calendar_opts=opts.CalendarOpts(range_="2020"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Calendar-基本示例", subtitle="我是副标题"),
            legend_opts=opts.LegendOpts(is_show=False),
            visualmap_opts=opts.VisualMapOpts(
                max_=25000,
                min_=1000,
                orient="horizontal",
                is_piecewise=True,
                pos_top="230px",
                pos_left="100px",
            )
        )
    )

calendar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3b266968525c4d749b1752f2e361adc1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3b266968525c4d749b1752f2e361adc1 = echarts.init(
#                     document.getElementById('3b266968525c4d749b1752f2e361adc1'), 'white', {renderer: 'canvas'});
#                 var option_3b266968525c4d749b1752f2e361adc1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "\u5fae\u4fe1\u6b65\u6570",
#             "data": [
#                 [
#                     "2020-01-01",
#                     3262
#                 ],
#                 [
#                     "2020-01-02",
#                     9440
#                 ],
#                 [
#                     "2020-01-03",
#                     21484
#                 ],
#                 [
#                     "2020-01-04",
#                     20044
#                 ],
#                 [
#                     "2020-01-05",
#                     15518
#                 ],
#                 [
#                     "2020-01-06",
#                     18482
#                 ],
#                 [
#                     "2020-01-07",
#                     10441
#                 ],
#                 [
#                     "2020-01-08",
#                     11520
#                 ],
#                 [
#                     "2020-01-09",
#                     21397
#                 ],
#                 [
#                     "2020-01-10",
#                     20683
#                 ],
#                 [
#                     "2020-01-11",
#                     2412
#                 ],
#                 [
#                     "2020-01-12",
#                     7295
#                 ],
#                 [
#                     "2020-01-13",
#                     12784
#                 ],
#                 [
#                     "2020-01-14",
#                     22508
#                 ],
#                 [
#                     "2020-01-15",
#                     14048
#                 ],
#                 [
#                     "2020-01-16",
#                     17029
#                 ],
#                 [
#                     "2020-01-17",
#                     21965
#                 ],
#                 [
#                     "2020-01-18",
#                     3870
#                 ],
#                 [
#                     "2020-01-19",
#                     1829
#                 ],
#                 [
#                     "2020-01-20",
#                     13017
#                 ],
#                 [
#                     "2020-01-21",
#                     11341
#                 ],
#                 [
#                     "2020-01-22",
#                     13088
#                 ],
#                 [
#                     "2020-01-23",
#                     4971
#                 ],
#                 [
#                     "2020-01-24",
#                     21079
#                 ],
#                 [
#                     "2020-01-25",
#                     19968
#                 ],
#                 [
#                     "2020-01-26",
#                     6489
#                 ],
#                 [
#                     "2020-01-27",
#                     1507
#                 ],
#                 [
#                     "2020-01-28",
#                     3198
#                 ],
#                 [
#                     "2020-01-29",
#                     24245
#                 ],
#                 [
#                     "2020-01-30",
#                     17978
#                 ],
#                 [
#                     "2020-01-31",
#                     5058
#                 ],
#                 [
#                     "2020-02-01",
#                     15498
#                 ],
#                 [
#                     "2020-02-02",
#                     14394
#                 ],
#                 [
#                     "2020-02-03",
#                     15210
#                 ],
#                 [
#                     "2020-02-04",
#                     11875
#                 ],
#                 [
#                     "2020-02-05",
#                     8954
#                 ],
#                 [
#                     "2020-02-06",
#                     8278
#                 ],
#                 [
#                     "2020-02-07",
#                     8699
#                 ],
#                 [
#                     "2020-02-08",
#                     10042
#                 ],
#                 [
#                     "2020-02-09",
#                     24149
#                 ],
#                 [
#                     "2020-02-10",
#                     4018
#                 ],
#                 [
#                     "2020-02-11",
#                     19252
#                 ],
#                 [
#                     "2020-02-12",
#                     3590
#                 ],
#                 [
#                     "2020-02-13",
#                     9375
#                 ],
#                 [
#                     "2020-02-14",
#                     23106
#                 ],
#                 [
#                     "2020-02-15",
#                     17831
#                 ],
#                 [
#                     "2020-02-16",
#                     24035
#                 ],
#                 [
#                     "2020-02-17",
#                     16207
#                 ],
#                 [
#                     "2020-02-18",
#                     12277
#                 ],
#                 [
#                     "2020-02-19",
#                     20286
#                 ],
#                 [
#                     "2020-02-20",
#                     13021
#                 ],
#                 [
#                     "2020-02-21",
#                     2936
#                 ],
#                 [
#                     "2020-02-22",
#                     4655
#                 ],
#                 [
#                     "2020-02-23",
#                     3587
#                 ],
#                 [
#                     "2020-02-24",
#                     7551
#                 ],
#                 [
#                     "2020-02-25",
#                     12561
#                 ],
#                 [
#                     "2020-02-26",
#                     12465
#                 ],
#                 [
#                     "2020-02-27",
#                     8353
#                 ],
#                 [
#                     "2020-02-28",
#                     21486
#                 ],
#                 [
#                     "2020-02-29",
#                     7966
#                 ],
#                 [
#                     "2020-03-01",
#                     2427
#                 ],
#                 [
#                     "2020-03-02",
#                     14188
#                 ],
#                 [
#                     "2020-03-03",
#                     3503
#                 ],
#                 [
#                     "2020-03-04",
#                     24063
#                 ],
#                 [
#                     "2020-03-05",
#                     11826
#                 ],
#                 [
#                     "2020-03-06",
#                     13692
#                 ],
#                 [
#                     "2020-03-07",
#                     20112
#                 ],
#                 [
#                     "2020-03-08",

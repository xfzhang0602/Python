# %% [markdown]
# 1. 打开图像并显示

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
im = np.array(Image.open('data/lena_gray.tif'))
#打开图像数据并转换为数组
plt.imshow(im,cmap = 'Greys_r')
plt.title("src")
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# 2. 对图像数据进行SVD变换

# %%
U,sigma,VT = np.linalg.svd(im)
print(U)
print('前30个特征值为：\n',sigma[:30])
# Out:
# [[-4.73295696e-02  2.79019414e-02 -1.52743980e-02 ... -6.66994435e-03
#    2.36442815e-02 -6.85365795e-17]
#  [-4.73295696e-02  2.79019414e-02 -1.52743980e-02 ...  1.66192229e-01
#   -1.36453679e-01 -6.43202468e-17]
#  [-4.73295696e-02  2.79019414e-02 -1.52743980e-02 ... -8.52871342e-01
#    6.92741025e-02  1.42602847e-16]
#  ...
#  [-4.16733544e-02  4.85763552e-02  2.18360056e-02 ...  8.72357742e-14
#    3.72687992e-14 -3.01245731e-17]
#  [-4.17296403e-02  4.80659473e-02  2.02981982e-02 ... -6.80705492e-15
#   -6.52602972e-15 -7.07106781e-01]
#  [-4.17296403e-02  4.80659473e-02  2.02981982e-02 ... -6.80705492e-15
#   -7.08114123e-15  7.07106781e-01]]
# 前30个特征值为：
#  [64735.58961147 10596.27478979  8175.35249857  6475.34501113
#   5883.41615919  5552.51711471  4588.02299704  4093.14961415
#   3375.16453232  3173.11282791  2672.56048429  2448.43420675
#   2404.79428552  2325.55444616  2181.4641553   2150.4772401
#   2087.64321903  1854.1383145   1737.95943175  1705.30863975
#   1637.21476014  1587.36621394  1449.20892739  1336.81087199
#   1322.89576783  1295.58056617  1216.65965841  1211.44475543
#   1146.29506658  1119.21111971]

# %% [markdown]
# 3. 分别只利用30个特征值和120个特征值重构图像

# %%
c = 30
r1 = (U[:,:c]).dot(np.diag(sigma[:c])).dot(VT[:c,:])
c = 120
r2 = (U[:,:c]).dot(np.diag(sigma[:c])).dot(VT[:c,:])
plt.subplot(1,2,1)
plt.imshow(r1.astype(np.uint8),cmap = 'Greys_r')
plt.title("nums_sigma = 30")
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(r2.astype(np.uint8),cmap = 'Greys_r')
plt.title("nums_sigma = 120")
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)
